# %%
import re
import nltk
from nltk.tokenize import PunktSentenceTokenizer

# %%
import wikipedia

# %%
wiki = wikipedia.summary('George.W.Bush',sentences=4)

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(wiki)

# %%
tokenized = custom_sent_tokenizer.tokenize(wiki)

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            
            print(chunked)
            for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
                print(subtree)

    except Exception as e:
        print(str(e))

process_content()
# Out:
# (S
#   (Chunk George/NNP Walker/NNP Bush/NNP)
#   (/(
#   (Chunk born/VBN July/NNP)
#   6/CD
#   ,/,
#   1946/CD
#   )/)
#   is/VBZ
#   an/DT
#   American/JJ
#   politician/NN
#   and/CC
#   businessman/NN
#   who/WP
#   served/VBD
#   as/IN
#   the/DT
#   43rd/CD
#   president/NN
#   of/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   from/IN
#   2001/CD
#   to/TO
#   2009/CD
#   ./.)
# (Chunk George/NNP Walker/NNP Bush/NNP)
# (Chunk born/VBN July/NNP)
# (Chunk United/NNP)
# (S
#   A/DT
#   member/NN
#   of/IN
#   the/DT
#   (Chunk Republican/NNP Party/NNP)
#   ,/,
#   he/PRP
#   had/VBD
#   previously/RB
#   served/VBN
#   as/IN
#   the/DT
#   46th/CD
#   governor/NN
#   of/IN
#   (Chunk Texas/NNP)
#   from/IN
#   1995/CD
#   to/TO
#   2000/CD
#   ./.)
# (Chunk Republican/NNP Party/NNP)
# (Chunk Texas/NNP)
# (S
#   (Chunk Bush/NNP)
#   is/VBZ
#   frequently/RB
#   referred/VBN
#   to/TO
#   as/IN
#   (Chunk George/NNP W./NNP Bush/NNP)
#   ,/,
#   (Chunk Bush/NNP Junior/NNP)
#   ,/,
#   or/CC
#   (Chunk Bush/NNP)
#   43/CD
#   to/TO
#   distinguish/VB
#   him/PRP
#   from/IN
#   his/PRP$
#   father/NN
#   ,/,
#   (Chunk George/NNP H./NNP W./NNP Bush/NNP)
#   ,/,
#   who/WP
#   served/VBD
#   as/IN
#   the/DT
#   41st/CD
#   president/NN
#   of/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   from/IN
#   1989/CD
#   to/TO
#   1993/CD
#   ./.)
# (Chunk Bush/NNP)
# (Chunk George/NNP W./NNP Bush/NNP)
# (Chunk Bush/NNP Junior/NNP)
# (Chunk Bush/NNP)
# (Chunk George/NNP H./NNP W./NNP Bush/NNP)
# (Chunk United/NNP)
# (S
#   (Chunk Bush/NNP)
#   is/VBZ
#   the/DT
#   eldest/JJS
#   son/NN
#   of/IN
#   (Chunk Barbara/NNP)
#   and/CC
#   (Chunk George/NNP H./NNP W./NNP Bush/NNP)
#   ,/,
#   and/CC
#   the/DT
#   second/JJ
#   son/NN
#   to/TO
#   become/VB
#   the/DT
#   (Chunk American/NNP president/NN)
#   after/IN
#   his/PRP$
#   father/NN
#   ,/,
#   the/DT
#   first/JJ
#   (Chunk being/VBG John/NNP Quincy/NNP Adams/NNP)
#   ./.)
# (Chunk Bush/NNP)
# (Chunk Barbara/NNP)
# (Chunk George/NNP H./NNP W./NNP Bush/NNP)
# (Chunk American/NNP president/NN)
# (Chunk being/VBG John/NNP Quincy/NNP Adams/NNP)
