# %%
import pandas as pd
import numpy as np

# %%
airlines = pd.read_csv('airlines_final.csv')
airlines.head()
# Out:
#      id        day      airline        destination    dest_region dest_size  \
# 0  1351    Tuesday  UNITED INTL             KANSAI           Asia       Hub
# 1   373     Friday       ALASKA  SAN JOSE DEL CABO  Canada/Mexico     Small
# 2  2820   Thursday        DELTA        LOS ANGELES        West US       Hub
# 3  1157    Tuesday    SOUTHWEST        LOS ANGELES        West US       Hub
# 4  2992  Wednesday     AMERICAN              MIAMI        East US       Hub
#
#   boarding_area   dept_time  wait_min     cleanliness         safety  \
# 0  Gates 91-102  12/31/2018       115           Clean        Neutral
# 1   Gates 50-59  12/31/2018       135           Clean      Very safe
# 2   Gates 40-48  12/31/2018        70         Average  Somewhat safe
# 3   Gates 20-39  12/31/2018       190           Clean      Very safe
# 4   Gates 50-59  12/31/2018       559  Somewhat clean      Very safe
#
#          satisfaction
# 0      Very satisfied
# 1      Very satisfied
# 2             Neutral
# ...

# %%
airlines['dept_time'] = airlines['dept_time'].str.replace('/','-')
airlines.head()
# Out:
#      id        day      airline        destination    dest_region dest_size  \
# 0  1351    Tuesday  UNITED INTL             KANSAI           Asia       Hub
# 1   373     Friday       ALASKA  SAN JOSE DEL CABO  Canada/Mexico     Small
# 2  2820   Thursday        DELTA        LOS ANGELES        West US       Hub
# 3  1157    Tuesday    SOUTHWEST        LOS ANGELES        West US       Hub
# 4  2992  Wednesday     AMERICAN              MIAMI        East US       Hub
#
#   boarding_area   dept_time  wait_min     cleanliness         safety  \
# 0  Gates 91-102  12-31-2018       115           Clean        Neutral
# 1   Gates 50-59  12-31-2018       135           Clean      Very safe
# 2   Gates 40-48  12-31-2018        70         Average  Somewhat safe
# 3   Gates 20-39  12-31-2018       190           Clean      Very safe
# 4   Gates 50-59  12-31-2018       559  Somewhat clean      Very safe
#
#          satisfaction
# 0      Very satisfied
# 1      Very satisfied
# 2             Neutral
# ...

# %%
assert airlines['dept_time'].str.contains('/ | &').any() == False

# %% [markdown]
# This asserts that the dept_time column values dont contain the symbols / and &.

# %% [markdown]
# ### Considering destinations with short names only

# %%
dest_length = airlines['destination'].str.len()

short_len = airlines[dest_length < 10]

print(short_len['destination'])
# Out:
# 0          KANSAI
# 4           MIAMI
# 5          NEWARK
# 8         TORONTO
# 9        PORTLAND
#           ...
# 2469    HONG KONG
# 2471       AUSTIN
# 2473      PHOENIX
# 2474      ORLANDO
# 2476      QINGDAO
# Name: destination, Length: 1476, dtype: object
